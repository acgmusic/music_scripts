# %%
from kaggle_auto_inf import *

cookie_dir = r"C:\Users\11527\AppData\Local\Google\Chrome\slnm_data2"
cache_dir = r"E:\music\src\vgmdb\cache\kaggle_2"
script_url = "https://www.kaggle.com/code/wangchiyi/vocal-check/edit"

while True:
    kaggle_ins = kaggle_vocal_check_inf(cookie_dir, cache_dir, script_url)
    kaggle_ins.login()
    kaggle_ins.open_script()
    # assert 0
    kaggle_ins.prepare()
    kaggle_ins.start()
    can_finish = kaggle_ins.running()
    res = kaggle_ins.new_res
    kaggle_ins.exit()
    if can_finish:
        kaggle_ins.exit()
        break
    print("retrying...")
# Out:
# start running...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# get total num fail, wait...
# total num: 1834
# cur ok:  1527
# cur ok:  1530
# cur ok:  1533
# cur ok:  1537
# cur ok:  1539
# cur ok:  1543
# cur ok:  1545
# cur ok:  1547
# cur ok:  1549
# cur ok:  1552
# cur ok:  1554
# cur ok:  1558
# cur ok:  1562
# cur ok:  1566
# cur ok:  1570
# ...
